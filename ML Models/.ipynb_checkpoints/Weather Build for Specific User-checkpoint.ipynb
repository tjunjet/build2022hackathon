# %%
import requests
import json
import geocoder
import today_weather
import pandas as pd
import random
import train_test_generation
# Out:
# 62.5

# %%
historical_weather_data_api_key = 'e873e86301b849268257b3b949de85b4'

# %%
#today_data = today_weather.gettemperaturedata("eb11283d82ed8ad579eca6904e3a6712")

# %%
#today_data

# %%
#YYYY-MM-DD
from datetime import date
import datetime
def gethistorical(api, period):
    today_data = today_weather.gettemperaturedata("eb11283d82ed8ad579eca6904e3a6712")
    g = geocoder.ip('me')
    lat, lon = g.latlng[0], g.latlng[1]
    api_key = api
    end = '20' + date.today().strftime("%y-%m-%d")
    start = '20' + (date.today() - datetime.timedelta(period)).strftime("%y-%m-%d")
    complete_url = f'https://api.weatherbit.io/v2.0/history/daily?lat={lat}&lon={lon}&start_date={start}&end_date={end}&key={api}'
    response = requests.get(complete_url)    
    data = response.json()
    final_data = [today_data]
    for day in data['data']:
        result = {
            'date' : day['datetime'], #Date (YYYY-MM-DD)
            'temperature' : day['temp'], #average daily temp in celcius
            'humidity' : day['rh'], 
            'precipitation' : random.randint(0,100), #Note we randomize this because we cant really get a prediction
                                                     # from historical data
            'windspeed' : day['wind_spd'] * 2.237 #in mph
        }
        final_data.append(result)

    return final_data

# %%
#'20' + (date.today() - datetime.timedelta(3000)).strftime("%y-%m-%d")
# Out:
# '2013-10-29'

# %%
#weather_data = gethistorical(historical_weather_data_api_key, 365)

# %%
#weather_data
# Out:
# [{'date': '2022-01-15',
#   'temperature': -7.19,
#   'humidity': 60,
#   'precipitation': 100,
#   'windspeed': 1.00665},
#  {'date': '2021-01-15',
#   'temperature': 3.6,
#   'humidity': 67.2,
#   'precipitation': 76,
#   'windspeed': 8.7243},
#  {'date': '2021-01-16',
#   'temperature': -1.1,
#   'humidity': 94.3,
#   'precipitation': 37,
#   'windspeed': 6.4873},
#  {'date': '2021-01-17',
#   'temperature': 0.2,
#   'humidity': 87.7,
#   'precipitation': 23,
#   'windspeed': 10.2902},
#  {'date': '2021-01-18',
#   'temperature': -0.8,
#   'humidity': 81.5,
#   'precipitation': 88,
#   'windspeed': 11.185},
#  {'date': '2021-01-19',
#   'temperature': 0.1,
#   'humidity': 66.3,
#   'precipitation': 58,
#   'windspeed': 11.185},
#  {'date': '2021-01-20',
#   'temperature': -2.5,
#   'humidity': 66.5,
#   'precipitation': 51,
#   'windspeed': 8.948},
#  {'date': '2021-01-21',
#   'temperature': 1.2,
#   'humidity': 59.4,
#   'precipitation': 59,
#   'windspeed': 14.3168},
#  {'date': '2021-01-22',
#   'temperature': 0.1,
#   'humidity': 62.2,
#   'precipitation': 1,
#   'windspeed': 10.961300000000001},
#  {'date': '2021-01-23',
#   'temperature': -6,
#   'humidity': 59.8,
#   'precipitation': 33,
#   'windspeed': 7.8295},
#  {'date': '2021-01-24',
#   'temperature': -5.6,
#   'humidity': 69.7,
#   'precipitation': 96,
#   'windspeed': 4.2503},
#  {'date': '2021-01-25',
#   'temperature': -1.2,
#   'humidity': 90.4,
#   'precipitation': 0,
#   'windspeed': 4.2503},
#  {'date': '2021-01-26',
#   'temperature': 2.7,
#   'humidity': 88.3,
#   'precipitation': 89,
#   'windspeed': 12.0798},
#  {'date': '2021-01-27',
#   'temperature': -1.4,
#   'humidity': 72.1,
#   'precipitation': 79,
#   'windspeed': 7.3821},
#  {'date': '2021-01-28',
#   'temperature': -5.5,
#   'humidity': 64.8,
#   'precipitation': 89,
#   'windspeed': 11.4087},
#  {'date': '2021-01-29',
#   'temperature': -6.4,
#   'humidity': 63.3,
#   'precipitation': 7,
#   'windspeed': 8.7243},
#  {'date': '2021-01-30',
#   'temperature': -5,
#   'humidity': 62,
#   'precipitation': 29,
#   'windspeed': 4.2503},
#  {'date': '2021-01-31',
#   'temperature': -1.5,
#   'humidity': 82.5,
#   'precipitation': 28,
#   'windspeed': 10.7376},
#  {'date': '2021-02-01',
#   'temperature': -1.4,
#   'humidity': 89.5,
#   'precipitation': 6,
#   'windspeed': 6.9347},
#  {'date': '2021-02-02',
#   'temperature': -2.9,
#   'humidity': 75,
#   'precipitation': 16,
#   'windspeed': 12.0798},
#  {'date': '2021-02-03',
#   'temperature': -2.2,
#   'humidity': 70.2,
#   'precipitation': 84,
#   'windspeed': 11.4087},
#  {'date': '2021-02-04',
#   'temperature': -3.1,
#   'humidity': 65.3,
#   'precipitation': 34,
#   'windspeed': 7.8295},
#  {'date': '2021-02-05',
#   'temperature': 0.6,
#   'humidity': 69.5,
#   'precipitation': 45,
#   'windspeed': 14.7642},
#  {'date': '2021-02-06',
#   'temperature': -2.5,
#   'humidity': 51.9,
#   'precipitation': 81,
#   'windspeed': 10.2902},
#  {'date': '2021-02-07',
#   'temperature': -5.1,
#   'humidity': 55.1,
#   'precipitation': 10,
#   'windspeed': 8.0532},
#  {'date': '2021-02-08',
#   'temperature': -6.6,
#   'humidity': 54.1,
#   'precipitation': 39,
#   'windspeed': 3.1318},
#  {'date': '2021-02-09',
#   'temperature': -2.9,
#   'humidity': 84,
#   'precipitation': 53,
#   'windspeed': 4.0266},
#  {'date': '2021-02-10',
#   'temperature': -4.5,
#   'humidity': 78.4,
#   'precipitation': 74,
#   'windspeed': 4.9214},
#  {'date': '2021-02-11',
#   'temperature': -4.1,
#   'humidity': 72.5,
#   'precipitation': 9,
#   'windspeed': 6.4873},
#  {'date': '2021-02-12',
#   'temperature': -3.9,
#   'humidity': 71.1,
#   'precipitation': 13,
#   'windspeed': 5.8162},
#  {'date': '2021-02-13',
#   'temperature': -3.1,
#   'humidity': 82.3,
#   'precipitation': 81,
#   'windspeed': 4.9214},
#  {'date': '2021-02-14',
#   'temperature': -3.7,
#   'humidity': 84.3,
#   'precipitation': 3,
#   'windspeed': 5.3688},
#  {'date': '2021-02-15',
#   'temperature': -2.4,
#   'humidity': 84.5,
#   'precipitation': 33,
#   'windspeed': 6.4873},
#  {'date': '2021-02-16',
#   'temperature': -3,
#   'humidity': 82.1,
#   'precipitation': 27,
#   'windspeed': 14.0931},
#  {'date': '2021-02-17',
#   'temperature': -7.7,
#   'humidity': 70.5,
#   'precipitation': 94,
#   'windspeed': 4.2503},
#  {'date': '2021-02-18',
#   'temperature': -3.4,
#   'humidity': 83.6,
#   'precipitation': 88,
#   'windspeed': 5.1451},
#  {'date': '2021-02-19',
#   'temperature': -3.6,
#   'humidity': 83,
#   'precipitation': 28,
#   'windspeed': 7.1584},
#  {'date': '2021-02-20',
#   'temperature': -7.3,
#   'humidity': 68.8,
#   'precipitation': 44,
#   'windspeed': 10.2902},
#  {'date': '2021-02-21',
#   'temperature': -5.1,
#   'humidity': 61.8,
#   'precipitation': 75,
#   'windspeed': 6.0399},
#  {'date': '2021-02-22',
#   'temperature': 2,
#   'humidity': 75.4,
#   'precipitation': 100,
#   'windspeed': 14.540500000000002},
#  {'date': '2021-02-23',
#   'temperature': 3.9,
#   'humidity': 66.7,
#   'precipitation': 44,
#   'windspeed': 14.0931},
#  {'date': '2021-02-24',
#   'temperature': 7.1,
#   'humidity': 65.3,
#   'precipitation': 54,
#   'windspeed': 12.9746},
#  {'date': '2021-02-25',
#   'temperature': 2.5,
#   'humidity': 57.5,
#   'precipitation': 50,
#   'windspeed': 7.8295},
#  {'date': '2021-02-26',
#   'temperature': 2.7,
#   'humidity': 55.7,
#   'precipitation': 1,
#   'windspeed': 7.8295},
#  {'date': '2021-02-27',
#   'temperature': 7.5,
#   'humidity': 73.8,
#   'precipitation': 24,
#   'windspeed': 7.8295},
#  {'date': '2021-02-28',
#   'temperature': 8.7,
#   'humidity': 92.5,
#   'precipitation': 36,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-03-01',
#   'temperature': 5.2,
#   'humidity': 72.8,
#   'precipitation': 60,
#   'windspeed': 12.9746},
#  {'date': '2021-03-02',
#   'temperature': -1.8,
#   'humidity': 47.4,
#   'precipitation': 86,
#   'windspeed': 7.3821},
#  {'date': '2021-03-03',
#   'temperature': 4.9,
#   'humidity': 44.5,
#   'precipitation': 24,
#   'windspeed': 9.8428},
#  {'date': '2021-03-04',
#   'temperature': 0.6,
#   'humidity': 65.2,
#   'precipitation': 36,
#   'windspeed': 10.961300000000001},
#  {'date': '2021-03-05',
#   'temperature': -2.8,
#   'humidity': 53.8,
#   'precipitation': 99,
#   'windspeed': 10.066500000000001},
#  {'date': '2021-03-06',
#   'temperature': -0.9,
#   'humidity': 51.9,
#   'precipitation': 95,
#   'windspeed': 8.5006},
#  {'date': '2021-03-07',
#   'temperature': -0.8,
#   'humidity': 50.1,
#   'precipitation': 71,
#   'windspeed': 4.474},
#  {'date': '2021-03-08',
#   'temperature': 3.4,
#   'humidity': 43,
#   'precipitation': 21,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-03-09',
#   'temperature': 12.3,
#   'humidity': 36.2,
#   'precipitation': 76,
#   'windspeed': 8.5006},
#  {'date': '2021-03-10',
#   'temperature': 13.6,
#   'humidity': 33.5,
#   'precipitation': 85,
#   'windspeed': 9.8428},
#  {'date': '2021-03-11',
#   'temperature': 14.8,
#   'humidity': 56.5,
#   'precipitation': 12,
#   'windspeed': 11.6324},
#  {'date': '2021-03-12',
#   'temperature': 10.6,
#   'humidity': 53.5,
#   'precipitation': 67,
#   'windspeed': 9.3954},
#  {'date': '2021-03-13',
#   'temperature': 3.6,
#   'humidity': 41.6,
#   'precipitation': 12,
#   'windspeed': 6.4873},
#  {'date': '2021-03-14',
#   'temperature': 5.3,
#   'humidity': 38.6,
#   'precipitation': 77,
#   'windspeed': 12.0798},
#  {'date': '2021-03-15',
#   'temperature': 0.4,
#   'humidity': 38,
#   'precipitation': 27,
#   'windspeed': 7.1584},
#  {'date': '2021-03-16',
#   'temperature': 8.7,
#   'humidity': 58.8,
#   'precipitation': 4,
#   'windspeed': 6.711},
#  {'date': '2021-03-17',
#   'temperature': 10.2,
#   'humidity': 62.7,
#   'precipitation': 45,
#   'windspeed': 4.9214},
#  {'date': '2021-03-18',
#   'temperature': 7.7,
#   'humidity': 88.9,
#   'precipitation': 53,
#   'windspeed': 8.948},
#  {'date': '2021-03-19',
#   'temperature': 2.9,
#   'humidity': 46.4,
#   'precipitation': 98,
#   'windspeed': 9.3954},
#  {'date': '2021-03-20',
#   'temperature': 6,
#   'humidity': 32.6,
#   'precipitation': 11,
#   'windspeed': 5.8162},
#  {'date': '2021-03-21',
#   'temperature': 10.3,
#   'humidity': 27.5,
#   'precipitation': 96,
#   'windspeed': 6.0399},
#  {'date': '2021-03-22',
#   'temperature': 12.2,
#   'humidity': 26.2,
#   'precipitation': 56,
#   'windspeed': 6.711},
#  {'date': '2021-03-23',
#   'temperature': 13,
#   'humidity': 39.2,
#   'precipitation': 18,
#   'windspeed': 9.6191},
#  {'date': '2021-03-24',
#   'temperature': 16.4,
#   'humidity': 64.5,
#   'precipitation': 13,
#   'windspeed': 8.7243},
#  {'date': '2021-03-25',
#   'temperature': 16.9,
#   'humidity': 64.1,
#   'precipitation': 11,
#   'windspeed': 7.1584},
#  {'date': '2021-03-26',
#   'temperature': 13.8,
#   'humidity': 69.1,
#   'precipitation': 51,
#   'windspeed': 16.1064},
#  {'date': '2021-03-27',
#   'temperature': 13.5,
#   'humidity': 59.2,
#   'precipitation': 16,
#   'windspeed': 4.9214},
#  {'date': '2021-03-28',
#   'temperature': 11.1,
#   'humidity': 78.2,
#   'precipitation': 27,
#   'windspeed': 13.6457},
#  {'date': '2021-03-29',
#   'temperature': 5.3,
#   'humidity': 54,
#   'precipitation': 71,
#   'windspeed': 9.3954},
#  {'date': '2021-03-30',
#   'temperature': 12.9,
#   'humidity': 38.1,
#   'precipitation': 45,
#   'windspeed': 9.3954},
#  {'date': '2021-03-31',
#   'temperature': 11.4,
#   'humidity': 74.3,
#   'precipitation': 90,
#   'windspeed': 9.6191},
#  {'date': '2021-04-01',
#   'temperature': -0.1,
#   'humidity': 72.4,
#   'precipitation': 95,
#   'windspeed': 12.750900000000001},
#  {'date': '2021-04-02',
#   'temperature': -0.9,
#   'humidity': 53.6,
#   'precipitation': 49,
#   'windspeed': 10.2902},
#  {'date': '2021-04-03',
#   'temperature': 4.4,
#   'humidity': 40.7,
#   'precipitation': 57,
#   'windspeed': 7.6058},
#  {'date': '2021-04-04',
#   'temperature': 12.8,
#   'humidity': 32.1,
#   'precipitation': 13,
#   'windspeed': 10.066500000000001},
#  {'date': '2021-04-05',
#   'temperature': 13.4,
#   'humidity': 40.4,
#   'precipitation': 47,
#   'windspeed': 4.474},
#  {'date': '2021-04-06',
#   'temperature': 18.1,
#   'humidity': 44.7,
#   'precipitation': 79,
#   'windspeed': 4.474},
#  {'date': '2021-04-07',
#   'temperature': 20.7,
#   'humidity': 45.2,
#   'precipitation': 57,
#   'windspeed': 6.2636},
#  {'date': '2021-04-08',
#   'temperature': 20.7,
#   'humidity': 50.9,
#   'precipitation': 69,
#   'windspeed': 9.8428},
#  {'date': '2021-04-09',
#   'temperature': 18,
#   'humidity': 63.3,
#   'precipitation': 34,
#   'windspeed': 9.6191},
#  {'date': '2021-04-10',
#   'temperature': 18.4,
#   'humidity': 64.5,
#   'precipitation': 39,
#   'windspeed': 9.8428},
#  {'date': '2021-04-11',
#   'temperature': 15.7,
#   'humidity': 72.7,
#   'precipitation': 69,
#   'windspeed': 9.6191},
#  {'date': '2021-04-12',
#   'temperature': 10.7,
#   'humidity': 81.4,
#   'precipitation': 80,
#   'windspeed': 7.6058},
#  {'date': '2021-04-13',
#   'temperature': 12.8,
#   'humidity': 70.1,
#   'precipitation': 46,
#   'windspeed': 4.474},
#  {'date': '2021-04-14',
#   'temperature': 13,
#   'humidity': 59,
#   'precipitation': 2,
#   'windspeed': 6.711},
#  {'date': '2021-04-15',
#   'temperature': 6.8,
#   'humidity': 65.9,
#   'precipitation': 6,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-04-16',
#   'temperature': 5.3,
#   'humidity': 83.1,
#   'precipitation': 47,
#   'windspeed': 9.1717},
#  {'date': '2021-04-17',
#   'temperature': 6.8,
#   'humidity': 78.5,
#   'precipitation': 0,
#   'windspeed': 4.6977},
#  {'date': '2021-04-18',
#   'temperature': 9,
#   'humidity': 64.8,
#   'precipitation': 43,
#   'windspeed': 4.2503},
#  {'date': '2021-04-19',
#   'temperature': 12.1,
#   'humidity': 55.5,
#   'precipitation': 55,
#   'windspeed': 5.8162},
#  {'date': '2021-04-20',
#   'temperature': 12.3,
#   'humidity': 54.8,
#   'precipitation': 26,
#   'windspeed': 8.7243},
#  {'date': '2021-04-21',
#   'temperature': 2.1,
#   'humidity': 68.6,
#   'precipitation': 12,
#   'windspeed': 9.6191},
#  {'date': '2021-04-22',
#   'temperature': 3.4,
#   'humidity': 52.4,
#   'precipitation': 36,
#   'windspeed': 10.066500000000001},
#  {'date': '2021-04-23',
#   'temperature': 8.5,
#   'humidity': 46.9,
#   'precipitation': 47,
#   'windspeed': 9.6191},
#  {'date': '2021-04-24',
#   'temperature': 9.6,
#   'humidity': 58.3,
#   'precipitation': 60,
#   'windspeed': 5.8162},
#  {'date': '2021-04-25',
#   'temperature': 10.2,
#   'humidity': 75.6,
#   'precipitation': 25,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-04-26',
#   'temperature': 8.5,
#   'humidity': 52.1,
#   'precipitation': 50,
#   'windspeed': 4.9214},
#  {'date': '2021-04-27',
#   'temperature': 19.3,
#   'humidity': 40.2,
#   'precipitation': 100,
#   'windspeed': 10.961300000000001},
#  {'date': '2021-04-28',
#   'temperature': 22,
#   'humidity': 53.5,
#   'precipitation': 46,
#   'windspeed': 10.513900000000001},
#  {'date': '2021-04-29',
#   'temperature': 17.5,
#   'humidity': 88.3,
#   'precipitation': 43,
#   'windspeed': 11.4087},
#  {'date': '2021-04-30',
#   'temperature': 9.8,
#   'humidity': 70.2,
#   'precipitation': 33,
#   'windspeed': 12.0798},
#  {'date': '2021-05-01',
#   'temperature': 9.9,
#   'humidity': 43.1,
#   'precipitation': 1,
#   'windspeed': 8.7243},
#  {'date': '2021-05-02',
#   'temperature': 20.1,
#   'humidity': 36.8,
#   'precipitation': 98,
#   'windspeed': 12.5272},
#  {'date': '2021-05-03',
#   'temperature': 16.8,
#   'humidity': 84.6,
#   'precipitation': 79,
#   'windspeed': 7.6058},
#  {'date': '2021-05-04',
#   'temperature': 18.6,
#   'humidity': 91.1,
#   'precipitation': 88,
#   'windspeed': 7.8295},
#  {'date': '2021-05-05',
#   'temperature': 11,
#   'humidity': 85.4,
#   'precipitation': 53,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-05-06',
#   'temperature': 9.3,
#   'humidity': 65,
#   'precipitation': 51,
#   'windspeed': 4.6977},
#  {'date': '2021-05-07',
#   'temperature': 7.8,
#   'humidity': 77.4,
#   'precipitation': 84,
#   'windspeed': 5.5925},
#  {'date': '2021-05-08',
#   'temperature': 7.7,
#   'humidity': 65.5,
#   'precipitation': 22,
#   'windspeed': 8.0532},
#  {'date': '2021-05-09',
#   'temperature': 5.7,
#   'humidity': 88.3,
#   'precipitation': 13,
#   'windspeed': 6.4873},
#  {'date': '2021-05-10',
#   'temperature': 8.8,
#   'humidity': 65,
#   'precipitation': 12,
#   'windspeed': 6.711},
#  {'date': '2021-05-11',
#   'temperature': 9.8,
#   'humidity': 50.8,
#   'precipitation': 42,
#   'windspeed': 7.6058},
#  {'date': '2021-05-12',
#   'temperature': 10,
#   'humidity': 50.2,
#   'precipitation': 1,
#   'windspeed': 6.4873},
#  {'date': '2021-05-13',
#   'temperature': 12.3,
#   'humidity': 42.2,
#   'precipitation': 50,
#   'windspeed': 5.3688},
#  {'date': '2021-05-14',
#   'temperature': 14.5,
#   'humidity': 36.8,
#   'precipitation': 8,
#   'windspeed': 4.474},
#  {'date': '2021-05-15',
#   'temperature': 15.2,
#   'humidity': 43.8,
#   'precipitation': 2,
#   'windspeed': 4.0266},
#  {'date': '2021-05-16',
#   'temperature': 16,
#   'humidity': 47.1,
#   'precipitation': 9,
#   'windspeed': 4.0266},
#  {'date': '2021-05-17',
#   'temperature': 16.3,
#   'humidity': 53.4,
#   'precipitation': 55,
#   'windspeed': 3.5792},
#  {'date': '2021-05-18',
#   'temperature': 19.3,
#   'humidity': 50.9,
#   'precipitation': 25,
#   'windspeed': 3.8029},
#  {'date': '2021-05-19',
#   'temperature': 21.7,
#   'humidity': 45.6,
#   'precipitation': 62,
#   'windspeed': 4.474},
#  {'date': '2021-05-20',
#   'temperature': 23,
#   'humidity': 49,
#   'precipitation': 90,
#   'windspeed': 5.3688},
#  {'date': '2021-05-21',
#   'temperature': 24.4,
#   'humidity': 41.8,
#   'precipitation': 50,
#   'windspeed': 6.4873},
#  {'date': '2021-05-22',
#   'temperature': 23.3,
#   'humidity': 50.1,
#   'precipitation': 42,
#   'windspeed': 6.2636},
#  {'date': '2021-05-23',
#   'temperature': 25.1,
#   'humidity': 51.2,
#   'precipitation': 3,
#   'windspeed': 7.6058},
#  {'date': '2021-05-24',
#   'temperature': 21.8,
#   'humidity': 79.6,
#   'precipitation': 22,
#   'windspeed': 4.0266},
#  {'date': '2021-05-25',
#   'temperature': 23.9,
#   'humidity': 67.5,
#   'precipitation': 6,
#   'windspeed': 8.5006},
#  {'date': '2021-05-26',
#   'temperature': 22.6,
#   'humidity': 70.8,
#   'precipitation': 54,
#   'windspeed': 10.7376},
#  {'date': '2021-05-27',
#   'temperature': 19.5,
#   'humidity': 65.8,
#   'precipitation': 25,
#   'windspeed': 5.8162},
#  {'date': '2021-05-28',
#   'temperature': 16.3,
#   'humidity': 79.4,
#   'precipitation': 15,
#   'windspeed': 6.9347},
#  {'date': '2021-05-29',
#   'temperature': 9.6,
#   'humidity': 94.2,
#   'precipitation': 58,
#   'windspeed': 6.711},
#  {'date': '2021-05-30',
#   'temperature': 10.2,
#   'humidity': 83.3,
#   'precipitation': 2,
#   'windspeed': 5.1451},
#  {'date': '2021-05-31',
#   'temperature': 15.3,
#   'humidity': 64.7,
#   'precipitation': 40,
#   'windspeed': 3.8029},
#  {'date': '2021-06-01',
#   'temperature': 17.7,
#   'humidity': 62.7,
#   'precipitation': 86,
#   'windspeed': 4.0266},
#  {'date': '2021-06-02',
#   'temperature': 17.8,
#   'humidity': 78.4,
#   'precipitation': 24,
#   'windspeed': 4.9214},
#  {'date': '2021-06-03',
#   'temperature': 19.1,
#   'humidity': 84.7,
#   'precipitation': 27,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-06-04',
#   'temperature': 21.8,
#   'humidity': 68.4,
#   'precipitation': 79,
#   'windspeed': 7.3821},
#  {'date': '2021-06-05',
#   'temperature': 24.4,
#   'humidity': 58.2,
#   'precipitation': 25,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-06-06',
#   'temperature': 24.8,
#   'humidity': 57.5,
#   'precipitation': 71,
#   'windspeed': 6.0399},
#  {'date': '2021-06-07',
#   'temperature': 25.1,
#   'humidity': 70.1,
#   'precipitation': 42,
#   'windspeed': 4.9214},
#  {'date': '2021-06-08',
#   'temperature': 25.3,
#   'humidity': 73.4,
#   'precipitation': 34,
#   'windspeed': 6.2636},
#  {'date': '2021-06-09',
#   'temperature': 23.5,
#   'humidity': 78.4,
#   'precipitation': 7,
#   'windspeed': 4.9214},
#  {'date': '2021-06-10',
#   'temperature': 22.6,
#   'humidity': 84.5,
#   'precipitation': 98,
#   'windspeed': 4.0266},
#  {'date': '2021-06-11',
#   'temperature': 21.9,
#   'humidity': 83,
#   'precipitation': 79,
#   'windspeed': 5.5925},
#  {'date': '2021-06-12',
#   'temperature': 21.3,
#   'humidity': 76.5,
#   'precipitation': 68,
#   'windspeed': 3.1318},
#  {'date': '2021-06-13',
#   'temperature': 22.1,
#   'humidity': 81.8,
#   'precipitation': 26,
#   'windspeed': 5.1451},
#  {'date': '2021-06-14',
#   'temperature': 19.8,
#   'humidity': 81.7,
#   'precipitation': 24,
#   'windspeed': 6.0399},
#  {'date': '2021-06-15',
#   'temperature': 18.5,
#   'humidity': 67.1,
#   'precipitation': 71,
#   'windspeed': 7.8295},
#  {'date': '2021-06-16',
#   'temperature': 16.6,
#   'humidity': 49.4,
#   'precipitation': 61,
#   'windspeed': 7.6058},
#  {'date': '2021-06-17',
#   'temperature': 18.5,
#   'humidity': 45.9,
#   'precipitation': 9,
#   'windspeed': 4.9214},
#  {'date': '2021-06-18',
#   'temperature': 21.6,
#   'humidity': 58,
#   'precipitation': 82,
#   'windspeed': 10.513900000000001},
#  {'date': '2021-06-19',
#   'temperature': 22.8,
#   'humidity': 75.5,
#   'precipitation': 27,
#   'windspeed': 8.948},
#  {'date': '2021-06-20',
#   'temperature': 24.6,
#   'humidity': 74.3,
#   'precipitation': 6,
#   'windspeed': 8.7243},
#  {'date': '2021-06-21',
#   'temperature': 23,
#   'humidity': 82.3,
#   'precipitation': 88,
#   'windspeed': 10.513900000000001},
#  {'date': '2021-06-22',
#   'temperature': 15.7,
#   'humidity': 72.2,
#   'precipitation': 100,
#   'windspeed': 6.711},
#  {'date': '2021-06-23',
#   'temperature': 16.8,
#   'humidity': 54.9,
#   'precipitation': 14,
#   'windspeed': 5.3688},
#  {'date': '2021-06-24',
#   'temperature': 20.9,
#   'humidity': 55.5,
#   'precipitation': 72,
#   'windspeed': 7.6058},
#  {'date': '2021-06-25',
#   'temperature': 22.6,
#   'humidity': 58.9,
#   'precipitation': 93,
#   'windspeed': 8.7243},
#  {'date': '2021-06-26',
#   'temperature': 24.2,
#   'humidity': 61.7,
#   'precipitation': 52,
#   'windspeed': 10.2902},
#  {'date': '2021-06-27',
#   'temperature': 26,
#   'humidity': 63,
#   'precipitation': 79,
#   'windspeed': 10.2902},
#  {'date': '2021-06-28',
#   'temperature': 27.2,
#   'humidity': 64.2,
#   'precipitation': 64,
#   'windspeed': 7.1584},
#  {'date': '2021-06-29',
#   'temperature': 28.2,
#   'humidity': 65.7,
#   'precipitation': 83,
#   'windspeed': 7.3821},
#  {'date': '2021-06-30',
#   'temperature': 23.3,
#   'humidity': 83.3,
#   'precipitation': 92,
#   'windspeed': 6.711},
#  {'date': '2021-07-01',
#   'temperature': 20.7,
#   'humidity': 92.2,
#   'precipitation': 37,
#   'windspeed': 5.5925},
#  {'date': '2021-07-02',
#   'temperature': 18.3,
#   'humidity': 73.9,
#   'precipitation': 59,
#   'windspeed': 7.6058},
#  {'date': '2021-07-03',
#   'temperature': 19.5,
#   'humidity': 65.8,
#   'precipitation': 97,
#   'windspeed': 7.1584},
#  {'date': '2021-07-04',
#   'temperature': 21.9,
#   'humidity': 65.7,
#   'precipitation': 58,
#   'windspeed': 4.6977},
#  {'date': '2021-07-05',
#   'temperature': 24.8,
#   'humidity': 71,
#   'precipitation': 78,
#   'windspeed': 6.4873},
#  {'date': '2021-07-06',
#   'temperature': 27.4,
#   'humidity': 67.6,
#   'precipitation': 75,
#   'windspeed': 8.7243},
#  {'date': '2021-07-07',
#   'temperature': 24.7,
#   'humidity': 77.4,
#   'precipitation': 69,
#   'windspeed': 7.8295},
#  {'date': '2021-07-08',
#   'temperature': 21.5,
#   'humidity': 89.8,
#   'precipitation': 94,
#   'windspeed': 7.8295},
#  {'date': '2021-07-09',
#   'temperature': 21.3,
#   'humidity': 83.5,
#   'precipitation': 36,
#   'windspeed': 7.1584},
#  {'date': '2021-07-10',
#   'temperature': 19.1,
#   'humidity': 67.8,
#   'precipitation': 96,
#   'windspeed': 3.3555},
#  {'date': '2021-07-11',
#   'temperature': 22.3,
#   'humidity': 81.1,
#   'precipitation': 90,
#   'windspeed': 7.6058},
#  {'date': '2021-07-12',
#   'temperature': 25,
#   'humidity': 79.3,
#   'precipitation': 88,
#   'windspeed': 7.3821},
#  {'date': '2021-07-13',
#   'temperature': 24.5,
#   'humidity': 78,
#   'precipitation': 46,
#   'windspeed': 8.5006},
#  {'date': '2021-07-14',
#   'temperature': 24.4,
#   'humidity': 71.8,
#   'precipitation': 95,
#   'windspeed': 8.0532},
#  {'date': '2021-07-15',
#   'temperature': 25.1,
#   'humidity': 70.8,
#   'precipitation': 72,
#   'windspeed': 8.948},
#  {'date': '2021-07-16',
#   'temperature': 23.6,
#   'humidity': 80.4,
#   'precipitation': 49,
#   'windspeed': 8.0532},
#  {'date': '2021-07-17',
#   'temperature': 21.6,
#   'humidity': 89.7,
#   'precipitation': 83,
#   'windspeed': 8.7243},
#  {'date': '2021-07-18',
#   'temperature': 21.4,
#   'humidity': 72,
#   'precipitation': 89,
#   'windspeed': 6.711},
#  {'date': '2021-07-19',
#   'temperature': 22.9,
#   'humidity': 68.4,
#   'precipitation': 89,
#   'windspeed': 4.474},
#  {'date': '2021-07-20',
#   'temperature': 23.7,
#   'humidity': 71,
#   'precipitation': 48,
#   'windspeed': 4.6977},
#  {'date': '2021-07-21',
#   'temperature': 22.5,
#   'humidity': 70.2,
#   'precipitation': 64,
#   'windspeed': 7.1584},
#  {'date': '2021-07-22',
#   'temperature': 20.1,
#   'humidity': 62.5,
#   'precipitation': 4,
#   'windspeed': 3.8029},
#  {'date': '2021-07-23',
#   'temperature': 21.9,
#   'humidity': 59.9,
#   'precipitation': 61,
#   'windspeed': 4.0266},
#  {'date': '2021-07-24',
#   'temperature': 23.3,
#   'humidity': 66.6,
#   'precipitation': 43,
#   'windspeed': 5.1451},
#  {'date': '2021-07-25',
#   'temperature': 24.9,
#   'humidity': 71.1,
#   'precipitation': 64,
#   'windspeed': 7.1584},
#  {'date': '2021-07-26',
#   'temperature': 25.4,
#   'humidity': 64,
#   'precipitation': 10,
#   'windspeed': 4.2503},
#  {'date': '2021-07-27',
#   'temperature': 25,
#   'humidity': 55.2,
#   'precipitation': 50,
#   'windspeed': 4.9214},
#  {'date': '2021-07-28',
#   'temperature': 25.2,
#   'humidity': 62.9,
#   'precipitation': 86,
#   'windspeed': 3.5792},
#  {'date': '2021-07-29',
#   'temperature': 23.2,
#   'humidity': 79.3,
#   'precipitation': 80,
#   'windspeed': 8.7243},
#  {'date': '2021-07-30',
#   'temperature': 22.4,
#   'humidity': 66.6,
#   'precipitation': 97,
#   'windspeed': 7.3821},
#  {'date': '2021-07-31',
#   'temperature': 19.6,
#   'humidity': 60,
#   'precipitation': 39,
#   'windspeed': 4.474},
#  {'date': '2021-08-01',
#   'temperature': 19.9,
#   'humidity': 72.8,
#   'precipitation': 40,
#   'windspeed': 6.2636},
#  {'date': '2021-08-02',
#   'temperature': 19,
#   'humidity': 68.2,
#   'precipitation': 17,
#   'windspeed': 4.9214},
#  {'date': '2021-08-03',
#   'temperature': 20.6,
#   'humidity': 58.9,
#   'precipitation': 61,
#   'windspeed': 5.1451},
#  {'date': '2021-08-04',
#   'temperature': 21.1,
#   'humidity': 70.1,
#   'precipitation': 81,
#   'windspeed': 3.5792},
#  {'date': '2021-08-05',
#   'temperature': 23.1,
#   'humidity': 64.3,
#   'precipitation': 14,
#   'windspeed': 4.2503},
#  {'date': '2021-08-06',
#   'temperature': 24.5,
#   'humidity': 61.7,
#   'precipitation': 59,
#   'windspeed': 6.0399},
#  {'date': '2021-08-07',
#   'temperature': 24,
#   'humidity': 70.9,
#   'precipitation': 35,
#   'windspeed': 5.5925},
#  {'date': '2021-08-08',
#   'temperature': 23.6,
#   'humidity': 74.9,
#   'precipitation': 98,
#   'windspeed': 5.3688},
#  {'date': '2021-08-09',
#   'temperature': 25.9,
#   'humidity': 67.1,
#   'precipitation': 6,
#   'windspeed': 7.1584},
#  {'date': '2021-08-10',
#   'temperature': 22.5,
#   'humidity': 82.6,
#   'precipitation': 86,
#   'windspeed': 8.948},
#  {'date': '2021-08-11',
#   'temperature': 22.9,
#   'humidity': 87.1,
#   'precipitation': 66,
#   'windspeed': 9.3954},
#  {'date': '2021-08-12',
#   'temperature': 24.8,
#   'humidity': 79.3,
#   'precipitation': 62,
#   'windspeed': 10.961300000000001},
#  {'date': '2021-08-13',
#   'temperature': 24.7,
#   'humidity': 77,
#   'precipitation': 46,
#   'windspeed': 8.7243},
#  {'date': '2021-08-14',
#   'temperature': 22.8,
#   'humidity': 75.8,
#   'precipitation': 90,
#   'windspeed': 5.5925},
#  {'date': '2021-08-15',
#   'temperature': 20.4,
#   'humidity': 71.3,
#   'precipitation': 48,
#   'windspeed': 5.3688},
#  {'date': '2021-08-16',
#   'temperature': 21,
#   'humidity': 87.1,
#   'precipitation': 42,
#   'windspeed': 4.6977},
#  {'date': '2021-08-17',
#   'temperature': 23.1,
#   'humidity': 86.7,
#   'precipitation': 77,
#   'windspeed': 5.1451},
#  {'date': '2021-08-18',
#   'temperature': 22.5,
#   'humidity': 92.7,
#   'precipitation': 12,
#   'windspeed': 6.2636},
#  {'date': '2021-08-19',
#   'temperature': 22.5,
#   'humidity': 86.7,
#   'precipitation': 11,
#   'windspeed': 4.0266},
#  {'date': '2021-08-20',
#   'temperature': 23.3,
#   'humidity': 76.5,
#   'precipitation': 3,
#   'windspeed': 3.8029},
#  {'date': '2021-08-21',
#   'temperature': 24.1,
#   'humidity': 64.1,
#   'precipitation': 95,
#   'windspeed': 3.5792},
#  {'date': '2021-08-22',
#   'temperature': 24.3,
#   'humidity': 68.2,
#   'precipitation': 38,
#   'windspeed': 3.8029},
#  {'date': '2021-08-23',
#   'temperature': 25.7,
#   'humidity': 71.8,
#   'precipitation': 97,
#   'windspeed': 6.4873},
#  {'date': '2021-08-24',
#   'temperature': 25.7,
#   'humidity': 66,
#   'precipitation': 95,
#   'windspeed': 3.5792},
#  {'date': '2021-08-25',
#   'temperature': 24.2,
#   'humidity': 82.1,
#   'precipitation': 89,
#   'windspeed': 5.1451},
#  {'date': '2021-08-26',
#   'temperature': 24,
#   'humidity': 83.1,
#   'precipitation': 11,
#   'windspeed': 3.8029},
#  {'date': '2021-08-27',
#   'temperature': 24.5,
#   'humidity': 82.1,
#   'precipitation': 93,
#   'windspeed': 4.2503},
#  {'date': '2021-08-28',
#   'temperature': 24.9,
#   'humidity': 83.3,
#   'precipitation': 56,
#   'windspeed': 4.6977},
#  {'date': '2021-08-29',
#   'temperature': 25.1,
#   'humidity': 80.4,
#   'precipitation': 47,
#   'windspeed': 6.0399},
#  {'date': '2021-08-30',
#   'temperature': 23.7,
#   'humidity': 80,
#   'precipitation': 62,
#   'windspeed': 5.5925},
#  {'date': '2021-08-31',
#   'temperature': 21.2,
#   'humidity': 93.3,
#   'precipitation': 10,
#   'windspeed': 3.5792},
#  {'date': '2021-09-01',
#   'temperature': 18.4,
#   'humidity': 92.4,
#   'precipitation': 15,
#   'windspeed': 7.8295},
#  {'date': '2021-09-02',
#   'temperature': 17.3,
#   'humidity': 67,
#   'precipitation': 36,
#   'windspeed': 6.4873},
#  {'date': '2021-09-03',
#   'temperature': 16.5,
#   'humidity': 67.1,
#   'precipitation': 62,
#   'windspeed': 4.0266},
#  {'date': '2021-09-04',
#   'temperature': 19.4,
#   'humidity': 68.4,
#   'precipitation': 59,
#   'windspeed': 4.474},
#  {'date': '2021-09-05',
#   'temperature': 19.7,
#   'humidity': 89.8,
#   'precipitation': 48,
#   'windspeed': 7.1584},
#  {'date': '2021-09-06',
#   'temperature': 19.8,
#   'humidity': 68.7,
#   'precipitation': 17,
#   'windspeed': 7.3821},
#  {'date': '2021-09-07',
#   'temperature': 20.5,
#   'humidity': 72.9,
#   'precipitation': 9,
#   'windspeed': 8.0532},
#  {'date': '2021-09-08',
#   'temperature': 18.9,
#   'humidity': 85.8,
#   'precipitation': 11,
#   'windspeed': 7.8295},
#  {'date': '2021-09-09',
#   'temperature': 18.1,
#   'humidity': 76.7,
#   'precipitation': 40,
#   'windspeed': 5.8162},
#  {'date': '2021-09-10',
#   'temperature': 16.9,
#   'humidity': 70.1,
#   'precipitation': 43,
#   'windspeed': 4.9214},
#  {'date': '2021-09-11',
#   'temperature': 17.9,
#   'humidity': 71.6,
#   'precipitation': 8,
#   'windspeed': 8.0532},
#  {'date': '2021-09-12',
#   'temperature': 22,
#   'humidity': 68.5,
#   'precipitation': 4,
#   'windspeed': 10.961300000000001},
#  {'date': '2021-09-13',
#   'temperature': 22.9,
#   'humidity': 77.9,
#   'precipitation': 26,
#   'windspeed': 9.1717},
#  {'date': '2021-09-14',
#   'temperature': 23.3,
#   'humidity': 77.1,
#   'precipitation': 15,
#   'windspeed': 8.5006},
#  {'date': '2021-09-15',
#   'temperature': 20.6,
#   'humidity': 87.3,
#   'precipitation': 3,
#   'windspeed': 7.3821},
#  {'date': '2021-09-16',
#   'temperature': 19.6,
#   'humidity': 86.6,
#   'precipitation': 87,
#   'windspeed': 4.474},
#  {'date': '2021-09-17',
#   'temperature': 22.9,
#   'humidity': 76,
#   'precipitation': 7,
#   'windspeed': 5.1451},
#  {'date': '2021-09-18',
#   'temperature': 23.7,
#   'humidity': 72.1,
#   'precipitation': 33,
#   'windspeed': 4.474},
#  {'date': '2021-09-19',
#   'temperature': 21.7,
#   'humidity': 68.8,
#   'precipitation': 90,
#   'windspeed': 3.8029},
#  {'date': '2021-09-20',
#   'temperature': 21.6,
#   'humidity': 72.3,
#   'precipitation': 99,
#   'windspeed': 6.9347},
#  {'date': '2021-09-21',
#   'temperature': 21.6,
#   'humidity': 69.7,
#   'precipitation': 5,
#   'windspeed': 8.7243},
#  {'date': '2021-09-22',
#   'temperature': 21.4,
#   'humidity': 80,
#   'precipitation': 36,
#   'windspeed': 10.961300000000001},
#  {'date': '2021-09-23',
#   'temperature': 14.5,
#   'humidity': 72.6,
#   'precipitation': 3,
#   'windspeed': 11.185},
#  {'date': '2021-09-24',
#   'temperature': 16.3,
#   'humidity': 57.2,
#   'precipitation': 82,
#   'windspeed': 10.2902},
#  {'date': '2021-09-25',
#   'temperature': 15.7,
#   'humidity': 67,
#   'precipitation': 30,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-09-26',
#   'temperature': 16.6,
#   'humidity': 56.8,
#   'precipitation': 21,
#   'windspeed': 10.066500000000001},
#  {'date': '2021-09-27',
#   'temperature': 19.3,
#   'humidity': 57.2,
#   'precipitation': 34,
#   'windspeed': 11.6324},
#  {'date': '2021-09-28',
#   'temperature': 19.5,
#   'humidity': 74.2,
#   'precipitation': 40,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-09-29',
#   'temperature': 16.2,
#   'humidity': 59.5,
#   'precipitation': 89,
#   'windspeed': 4.0266},
#  {'date': '2021-09-30',
#   'temperature': 15.3,
#   'humidity': 65.3,
#   'precipitation': 78,
#   'windspeed': 4.0266},
#  {'date': '2021-10-01',
#   'temperature': 15.1,
#   'humidity': 66.2,
#   'precipitation': 50,
#   'windspeed': 2.6844},
#  {'date': '2021-10-02',
#   'temperature': 15.8,
#   'humidity': 68.8,
#   'precipitation': 87,
#   'windspeed': 5.3688},
#  {'date': '2021-10-03',
#   'temperature': 19.3,
#   'humidity': 81.5,
#   'precipitation': 56,
#   'windspeed': 7.3821},
#  {'date': '2021-10-04',
#   'temperature': 20.5,
#   'humidity': 81.6,
#   'precipitation': 63,
#   'windspeed': 6.2636},
#  {'date': '2021-10-05',
#   'temperature': 20.3,
#   'humidity': 79.2,
#   'precipitation': 78,
#   'windspeed': 3.3555},
#  {'date': '2021-10-06',
#   'temperature': 21.1,
#   'humidity': 78.2,
#   'precipitation': 24,
#   'windspeed': 5.1451},
#  {'date': '2021-10-07',
#   'temperature': 21.1,
#   'humidity': 78.7,
#   'precipitation': 31,
#   'windspeed': 4.9214},
#  {'date': '2021-10-08',
#   'temperature': 21.1,
#   'humidity': 75.4,
#   'precipitation': 41,
#   'windspeed': 4.6977},
#  {'date': '2021-10-09',
#   'temperature': 18.8,
#   'humidity': 81.6,
#   'precipitation': 92,
#   'windspeed': 7.1584},
#  {'date': '2021-10-10',
#   'temperature': 19.2,
#   'humidity': 72.1,
#   'precipitation': 7,
#   'windspeed': 7.1584},
#  {'date': '2021-10-11',
#   'temperature': 19.4,
#   'humidity': 73,
#   'precipitation': 90,
#   'windspeed': 5.8162},
#  {'date': '2021-10-12',
#   'temperature': 19.6,
#   'humidity': 73.5,
#   'precipitation': 22,
#   'windspeed': 7.1584},
#  {'date': '2021-10-13',
#   'temperature': 18.9,
#   'humidity': 77,
#   'precipitation': 99,
#   'windspeed': 5.3688},
#  {'date': '2021-10-14',
#   'temperature': 18.6,
#   'humidity': 80.8,
#   'precipitation': 68,
#   'windspeed': 6.0399},
#  {'date': '2021-10-15',
#   'temperature': 22,
#   'humidity': 78.7,
#   'precipitation': 54,
#   'windspeed': 6.4873},
#  {'date': '2021-10-16',
#   'temperature': 15.6,
#   'humidity': 80.3,
#   'precipitation': 34,
#   'windspeed': 8.276900000000001},
#  {'date': '2021-10-17',
#   'temperature': 11.2,
#   'humidity': 60.3,
#   'precipitation': 61,
#   'windspeed': 9.6191},
#  {'date': '2021-10-18',
#   'temperature': 11.7,
#   'humidity': 54.9,
#   'precipitation': 9,
#   'windspeed': 8.5006},
#  {'date': '2021-10-19',
#   'temperature': 13.5,
#   'humidity': 57.1,
#   'precipitation': 48,
#   'windspeed': 8.5006},
#  {'date': '2021-10-20',
#   'temperature': 15.7,
#   'humidity': 56.7,
#   'precipitation': 73,
#   'windspeed': 8.0532},
#  {'date': '2021-10-21',
#   'temperature': 15.3,
#   'humidity': 73.4,
#   'precipitation': 74,
#   'windspeed': 10.2902},
#  {'date': '2021-10-22',
#   'temperature': 11,
#   'humidity': 84.9,
#   'precipitation': 36,
#   'windspeed': 6.9347},
#  {'date': '2021-10-23',
#   'temperature': 9,
#   'humidity': 82.8,
#   'precipitation': 67,
#   'windspeed': 4.6977},
#  {'date': '2021-10-24',
#   'temperature': 12.2,
#   'humidity': 86,
#   'precipitation': 28,
#   'windspeed': 5.3688},
#  {'date': '2021-10-25',
#   'temperature': 16.5,
#   'humidity': 67.8,
#   'precipitation': 72,
#   'windspeed': 9.1717},
#  {'date': '2021-10-26',
#   'temperature': 9.6,
#   'humidity': 81.8,
#   'precipitation': 85,
#   'windspeed': 11.8561},
#  {'date': '2021-10-27',
#   'temperature': 10,
#   'humidity': 83.5,
#   'precipitation': 36,
#   'windspeed': 5.8162},
#  {'date': '2021-10-28',
#   'temperature': 12.7,
#   'humidity': 77,
#   'precipitation': 98,
#   'windspeed': 7.3821},
#  {'date': '2021-10-29',
#   'temperature': 11.9,
#   'humidity': 86,
#   'precipitation': 36,
#   'windspeed': 7.3821},
#  {'date': '2021-10-30',
#   'temperature': 10.9,
#   'humidity': 89.5,
#   'precipitation': 23,
#   'windspeed': 3.1318},
#  {'date': '2021-10-31',
#   'temperature': 11.9,
#   'humidity': 79.3,
#   'precipitation': 15,
#   'windspeed': 9.1717},
#  {'date': '2021-11-01',
#   'temperature': 9.2,
#   'humidity': 55.5,
#   'precipitation': 57,
#   'windspeed': 8.0532},
#  {'date': '2021-11-02',
#   'temperature': 6.8,
#   'humidity': 51.7,
#   'precipitation': 12,
#   'windspeed': 6.9347},
#  {'date': '2021-11-03',
#   'temperature': 4.3,
#   'humidity': 55.3,
#   'precipitation': 78,
#   'windspeed': 6.0399},
#  {'date': '2021-11-04',
#   'temperature': 3.8,
#   'humidity': 59,
#   'precipitation': 16,
#   'windspeed': 3.8029},
#  {'date': '2021-11-05',
#   'temperature': 3.7,
#   'humidity': 63.5,
#   'precipitation': 31,
#   'windspeed': 3.1318},
#  {'date': '2021-11-06',
#   'temperature': 6.1,
#   'humidity': 49.8,
#   'precipitation': 62,
#   'windspeed': 4.6977},
#  {'date': '2021-11-07',
#   'temperature': 7.3,
#   'humidity': 54,
#   'precipitation': 9,
#   'windspeed': 4.9214},
#  {'date': '2021-11-08',
#   'temperature': 10.3,
#   'humidity': 56.3,
#   'precipitation': 43,
#   'windspeed': 6.4873},
#  {'date': '2021-11-09',
#   'temperature': 13.7,
#   'humidity': 48.8,
#   'precipitation': 2,
#   'windspeed': 7.3821},
#  {'date': '2021-11-10',
#   'temperature': 13,
#   'humidity': 54.1,
#   'precipitation': 87,
#   'windspeed': 5.1451},
#  {'date': '2021-11-11',
#   'temperature': 15.2,
#   'humidity': 48.8,
#   'precipitation': 86,
#   'windspeed': 10.2902},
#  {'date': '2021-11-12',
#   'temperature': 10.3,
#   'humidity': 59.6,
#   'precipitation': 82,
#   'windspeed': 9.8428},
#  {'date': '2021-11-13',
#   'temperature': 3.7,
#   'humidity': 70.5,
#   'precipitation': 44,
#   'windspeed': 12.0798},
#  {'date': '2021-11-14',
#   'temperature': 2.3,
#   'humidity': 77.8,
#   'precipitation': 33,
#   'windspeed': 10.2902},
#  {'date': '2021-11-15',
#   'temperature': 2.5,
#   'humidity': 73,
#   'precipitation': 58,
#   'windspeed': 12.3035},
#  {'date': '2021-11-16',
#   'temperature': 3.4,
#   'humidity': 71,
#   'precipitation': 69,
#   'windspeed': 4.2503},
#  {'date': '2021-11-17',
#   'temperature': 12.7,
#   'humidity': 65.8,
#   'precipitation': 71,
#   'windspeed': 9.6191},
#  {'date': '2021-11-18',
#   'temperature': 9.5,
#   'humidity': 71.5,
#   'precipitation': 5,
#   'windspeed': 10.2902},
#  {'date': '2021-11-19',
#   'temperature': 0.9,
#   'humidity': 58.7,
#   'precipitation': 14,
#   'windspeed': 8.5006},
#  {'date': '2021-11-20',
#   'temperature': 3.2,
#   'humidity': 54.7,
#   'precipitation': 94,
#   'windspeed': 6.2636},
#  {'date': '2021-11-21',
#   'temperature': 6.5,
#   'humidity': 57.5,
#   'precipitation': 70,
#   'windspeed': 7.6058},
#  {'date': '2021-11-22',
#   'temperature': 2.7,
#   'humidity': 60.5,
#   'precipitation': 13,
#   'windspeed': 9.8428},
#  {'date': '2021-11-23',
#   'temperature': -0.6,
#   'humidity': 55.2,
#   'precipitation': 59,
#   'windspeed': 6.9347},
#  {'date': '2021-11-24',
#   'temperature': 2,
#   'humidity': 49.3,
#   'precipitation': 90,
#   'windspeed': 7.1584},
#  {'date': '2021-11-25',
#   'temperature': 7.5,
#   'humidity': 57.5,
#   'precipitation': 65,
#   'windspeed': 10.066500000000001},
#  {'date': '2021-11-26',
#   'temperature': 0.3,
#   'humidity': 65.3,
#   'precipitation': 5,
#   'windspeed': 12.3035},
#  {'date': '2021-11-27',
#   'temperature': -0.3,
#   'humidity': 60.3,
#   'precipitation': 70,
#   'windspeed': 8.0532},
#  {'date': '2021-11-28',
#   'temperature': 2.8,
#   'humidity': 67.9,
#   'precipitation': 77,
#   'windspeed': 10.513900000000001},
#  {'date': '2021-11-29',
#   'temperature': 1.3,
#   'humidity': 62.6,
#   'precipitation': 88,
#   'windspeed': 7.6058},
#  {'date': '2021-11-30',
#   'temperature': 3.7,
#   'humidity': 66.5,
#   'precipitation': 49,
#   'windspeed': 11.185},
#  {'date': '2021-12-01',
#   'temperature': 5.3,
#   'humidity': 69.8,
#   'precipitation': 23,
#   'windspeed': 7.3821},
#  {'date': '2021-12-02',
#   'temperature': 11.2,
#   'humidity': 67,
#   'precipitation': 83,
#   'windspeed': 15.659},
#  {'date': '2021-12-03',
#   'temperature': 4.5,
#   'humidity': 68.9,
#   'precipitation': 78,
#   'windspeed': 5.3688},
#  {'date': '2021-12-04',
#   'temperature': 5.2,
#   'humidity': 55.9,
#   'precipitation': 23,
#   'windspeed': 5.3688},
#  {'date': '2021-12-05',
#   'temperature': 5.9,
#   'humidity': 50,
#   'precipitation': 72,
#   'windspeed': 7.8295},
#  {'date': '2021-12-06',
#   'temperature': 7.9,
#   'humidity': 69.5,
#   'precipitation': 47,
#   'windspeed': 14.7642},
#  {'date': '2021-12-07',
#   'temperature': -2.2,
#   'humidity': 58.6,
#   'precipitation': 18,
#   'windspeed': 6.2636},
#  {'date': '2021-12-08',
#   'temperature': -1.5,
#   'humidity': 69.6,
#   'precipitation': 17,
#   'windspeed': 6.0399},
#  {'date': '2021-12-09',
#   'temperature': 0.4,
#   'humidity': 68.2,
#   'precipitation': 36,
#   'windspeed': 6.4873},
#  {'date': '2021-12-10',
#   'temperature': 11.1,
#   'humidity': 56.4,
#   'precipitation': 84,
#   'windspeed': 6.9347},
#  {'date': '2021-12-11',
#   'temperature': 11.9,
#   'humidity': 78.7,
#   'precipitation': 69,
#   'windspeed': 15.8827},
#  {'date': '2021-12-12',
#   'temperature': 2.7,
#   'humidity': 55.5,
#   'precipitation': 87,
#   'windspeed': 10.2902},
#  {'date': '2021-12-13',
#   'temperature': 4.1,
#   'humidity': 45.7,
#   'precipitation': 80,
#   'windspeed': 8.7243},
#  {'date': '2021-12-14',
#   'temperature': 5.8,
#   'humidity': 48,
#   'precipitation': 61,
#   'windspeed': 4.9214},
#  {'date': '2021-12-15',
#   'temperature': 10.2,
#   'humidity': 39,
#   'precipitation': 60,
#   'windspeed': 8.5006},
#  {'date': '2021-12-16',
#   'temperature': 15.3,
#   'humidity': 49.8,
#   'precipitation': 5,
#   'windspeed': 13.8694},
#  {'date': '2021-12-17',
#   'temperature': 5.8,
#   'humidity': 52.6,
#   'precipitation': 11,
#   'windspeed': 6.2636},
#  {'date': '2021-12-18',
#   'temperature': 6.4,
#   'humidity': 90.2,
#   'precipitation': 2,
#   'windspeed': 7.6058},
#  {'date': '2021-12-19',
#   'temperature': 0.5,
#   'humidity': 70.3,
#   'precipitation': 38,
#   'windspeed': 8.948},
#  {'date': '2021-12-20',
#   'temperature': 0.8,
#   'humidity': 58.2,
#   'precipitation': 55,
#   'windspeed': 6.0399},
#  {'date': '2021-12-21',
#   'temperature': 1.1,
#   'humidity': 63,
#   'precipitation': 42,
#   'windspeed': 7.1584},
#  {'date': '2021-12-22',
#   'temperature': -0.2,
#   'humidity': 59,
#   'precipitation': 11,
#   'windspeed': 9.6191},
#  {'date': '2021-12-23',
#   'temperature': -1.3,
#   'humidity': 54.6,
#   'precipitation': 85,
#   'windspeed': 8.5006},
#  {'date': '2021-12-24',
#   'temperature': 11.6,
#   'humidity': 40.9,
#   'precipitation': 19,
#   'windspeed': 10.2902},
#  {'date': '2021-12-25',
#   'temperature': 12.5,
#   'humidity': 83.4,
#   'precipitation': 91,
#   'windspeed': 12.3035},
#  {'date': '2021-12-26',
#   'temperature': 4.9,
#   'humidity': 72.6,
#   'precipitation': 44,
#   'windspeed': 5.8162},
#  {'date': '2021-12-27',
#   'temperature': 5.7,
#   'humidity': 84.8,
#   'precipitation': 99,
#   'windspeed': 7.8295},
#  {'date': '2021-12-28',
#   'temperature': 5.9,
#   'humidity': 73.6,
#   'precipitation': 73,
#   'windspeed': 7.1584},
#  {'date': '2021-12-29',
#   'temperature': 8.3,
#   'humidity': 89.7,
#   'precipitation': 70,
#   'windspeed': 5.1451},
#  {'date': '2021-12-30',
#   'temperature': 8.6,
#   'humidity': 88,
#   'precipitation': 88,
#   'windspeed': 4.474},
#  {'date': '2021-12-31',
#   'temperature': 10.1,
#   'humidity': 77.6,
#   'precipitation': 23,
#   'windspeed': 6.2636},
#  {'date': '2022-01-12',
#   'temperature': 1.9,
#   'humidity': 44.5,
#   'precipitation': 88,
#   'windspeed': 11.6324},
#  {'date': '2022-01-14',
#   'temperature': 0.3,
#   'humidity': 79.8,
#   'precipitation': 80,
#   'windspeed': 8.7243},
#  {'date': '2022-01-09',
#   'temperature': 3.1,
#   'humidity': 76.8,
#   'precipitation': 7,
#   'windspeed': 11.4087},
#  {'date': '2022-01-13',
#   'temperature': 3.2,
#   'humidity': 70.3,
#   'precipitation': 25,
#   'windspeed': 6.0399},
#  {'date': '2022-01-11',
#   'temperature': -8.1,
#   'humidity': 57.5,
#   'precipitation': 22,
#   'windspeed': 8.7243},
#  {'date': '2022-01-10',
#   'temperature': -6.5,
#   'humidity': 61.7,
#   'precipitation': 97,
#   'windspeed': 11.4087},
#  {'date': '2022-01-08',
#   'temperature': -6.1,
#   'humidity': 62.8,
#   'precipitation': 30,
#   'windspeed': 5.8162},
#  {'date': '2022-01-06',
#   'temperature': -4.7,
#   'humidity': 65.5,
#   'precipitation': 28,
#   'windspeed': 9.3954},
#  {'date': '2022-01-04',
#   'temperature': -1.7,
#   'humidity': 62.9,
#   'precipitation': 97,
#   'windspeed': 6.9347},
#  {'date': '2022-01-07',
#   'temperature': -7.8,
#   'humidity': 71.9,
#   'precipitation': 21,
#   'windspeed': 10.513900000000001},
#  {'date': '2022-01-05',
#   'temperature': 5.8,
#   'humidity': 45.1,
#   'precipitation': 23,
#   'windspeed': 14.540500000000002},
#  {'date': '2022-01-01',
#   'temperature': 12,
#   'humidity': 92.4,
#   'precipitation': 26,
#   'windspeed': 7.1584},
#  {'date': '2022-01-03',
#   'temperature': -3.7,
#   'humidity': 64.7,
#   'precipitation': 78,
#   'windspeed': 8.276900000000001},
#  {'date': '2022-01-02',
#   'temperature': 2.9,
#   'humidity': 88,
#   'precipitation': 62,
#   'windspeed': 8.5006}]

# %%
#weather_df = pd.DataFrame(weather_data)

# %%
#weather_df
# Out:
#            date  temperature  humidity  precipitation  windspeed
# 0    2022-01-15        -7.19      60.0            100    1.00665
# 1    2021-01-15         3.60      67.2             76    8.72430
# 2    2021-01-16        -1.10      94.3             37    6.48730
# 3    2021-01-17         0.20      87.7             23   10.29020
# 4    2021-01-18        -0.80      81.5             88   11.18500
# ..          ...          ...       ...            ...        ...
# 361  2022-01-07        -7.80      71.9             21   10.51390
# 362  2022-01-05         5.80      45.1             23   14.54050
# 363  2022-01-01        12.00      92.4             26    7.15840
# 364  2022-01-03        -3.70      64.7             78    8.27690
# 365  2022-01-02         2.90      88.0             62    8.50060
#
# [366 rows x 5 columns]

# %%
def userDataframe(sex, age, height, weight, preference_factor):
        BMI = weight/(height**2)*10000
        #male
        if sex == 0:
            fatpercentage = (1.20 * BMI) + (0.23 * age) - 16.2

        elif sex == 1:
            fatpercentage = (1.20 * BMI) + (0.23 * age) - 5.4

        #adjustment for negative fatpercentage
        if fatpercentage < 0:
            fatpercentage = 1
            
        cold_resistance = train_test_generation.coldresistance(sex, age, fatpercentage, BMI)
        
        df = pd.DataFrame([[sex, age, height, weight, preference_factor, fatpercentage, BMI, cold_resistance]], columns = ['sex', 'age', 'height', 'weight', 'preference_factor', 'fatpercentage', 'BMI', 'cold_resistance'])
        df['adjusted_cold_resistance'] = (df['cold_resistance'] * (df['preference_factor']/100))
        return df

# %%
def returnFinalDataframe(sex, age, height, weight, preference_factor, api, period):
    weatherdata = gethistorical(api, period)
    weather_df = weather_df = pd.DataFrame(weather_data)
    
    user_df = userDataframe(sex, age, height, weight, preference_factor)
    duplicated_df = pd.concat([user_df] * weather_df.shape[0], ignore_index = True)
    combined_df = pd.concat([duplicated_df, weather_df], axis = 1)
    for article in train_test_generation.clothesmap:
        combined_df[article] = combined_df.apply(lambda row : train_test_generation.predictusingheatscore(row['temperature'], row['adjusted_cold_resistance'], train_test_generation.heatmap,row['windspeed'], row['precipitation'])[train_test_generation.clothesmap[article]], axis = 1)
    combined_df['scoring_difference'] = combined_df.apply(lambda row : train_test_generation.getdifference(row['temperature'], row['adjusted_cold_resistance'], train_test_generation.heatmap, row['windspeed'], row['precipitation']), axis = 1)
    # newly added user_feedback
    combined_df['user_feedback'] = combined_df.apply(lambda row : train_test_generation.getUserFeedback(row['scoring_difference']), axis = 1)
    return combined_df

# %%
#dataf = returnFinalDataframe(0,25, 170, 57, 95, 'e873e86301b849268257b3b949de85b4', 365)

# %%
#dataf.head()
# Out:
#    sex  age  height  weight  preference_factor  fatpercentage        BMI  \
# 0    0   25     170      57                 95       13.21782  19.723183
# 1    0   25     170      57                 95       13.21782  19.723183
# 2    0   25     170      57                 95       13.21782  19.723183
# 3    0   25     170      57                 95       13.21782  19.723183
# 4    0   25     170      57                 95       13.21782  19.723183
#
#    cold_resistance  adjusted_cold_resistance        date  ...  hoodie  fleece  \
# 0             57.5                    54.625  2022-01-15  ...    True   False
# 1             57.5                    54.625  2021-01-15  ...   False   False
# 2             57.5                    54.625  2021-01-16  ...    True   False
# 3             57.5                    54.625  2021-01-17  ...    True   False
# 4             57.5                    54.625  2021-01-18  ...    True   False
#
#     wool  light_down  thick_down  wind_breaker  umbrella  winter_boots  \
# 0   True        True        True         False      True          True
# 1  False       False        True         False      True          True
# 2  False        True        True         False     False         False
# 3  False        True        True         False     False         False
# 4  False        True        True         False      True          True
#
#    scoring_difference  user_feedback
# 0           -0.025000              1
# 1           -1.958333              1
# 2           -0.625000              1
# 3           -9.291667              0
# 4           -2.625000              1
#
# [5 rows x 25 columns]

# %%
#dataf
# Out:
#      sex  age  height  weight  preference_factor  fatpercentage        BMI  \
# 0      0   25     170      57                 95       13.21782  19.723183
# 1      0   25     170      57                 95       13.21782  19.723183
# 2      0   25     170      57                 95       13.21782  19.723183
# 3      0   25     170      57                 95       13.21782  19.723183
# 4      0   25     170      57                 95       13.21782  19.723183
# ..   ...  ...     ...     ...                ...            ...        ...
# 361    0   25     170      57                 95       13.21782  19.723183
# 362    0   25     170      57                 95       13.21782  19.723183
# 363    0   25     170      57                 95       13.21782  19.723183
# 364    0   25     170      57                 95       13.21782  19.723183
# 365    0   25     170      57                 95       13.21782  19.723183
#
#      cold_resistance  adjusted_cold_resistance        date  ...  hoodie  \
# 0               57.5                    54.625  2022-01-15  ...    True
# 1               57.5                    54.625  2021-01-15  ...   False
# 2               57.5                    54.625  2021-01-16  ...    True
# 3               57.5                    54.625  2021-01-17  ...    True
# 4               57.5                    54.625  2021-01-18  ...    True
# ..               ...                       ...         ...  ...     ...
# 361             57.5                    54.625  2022-01-07  ...    True
# 362             57.5                    54.625  2022-01-05  ...    True
# 363             57.5                    54.625  2022-01-01  ...    True
# 364             57.5                    54.625  2022-01-03  ...   False
# 365             57.5                    54.625  2022-01-02  ...    True
#
#      fleece   wool  light_down  thick_down  wind_breaker  umbrella  \
# 0     False   True        True        True         False      True
# 1     False  False       False        True         False      True
# 2     False  False        True        True         False     False
# 3     False  False        True        True         False     False
# 4     False  False        True        True         False      True
# ..      ...    ...         ...         ...           ...       ...
# 361    True   True        True        True         False     False
# 362    True  False       False        True         False     False
# 363   False  False       False       False         False     False
# 364   False  False        True        True         False      True
# 365   False  False       False        True         False      True
#
#      winter_boots  scoring_difference  user_feedback
# 0            True           -0.025000              1
# 1            True           -1.958333              1
# 2           False           -0.625000              1
# 3           False           -9.291667              0
# 4            True           -2.625000              1
# ..            ...                 ...            ...
# 361         False          -15.958333              0
# 362         False          -16.625000              0
# 363         False           -7.958333              0
# 364          True           -3.291667              1
# 365          True           -7.291667              0
#
# [366 rows x 25 columns]
