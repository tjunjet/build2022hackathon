# %%
import numpy as np
import pandas as pd
import random
import datetime
from sklearn.model_selection import train_test_split
from datetime import date
import tensorflow as tf
import train_test_generation
from sklearn.model_selection import GridSearchCV
# Out:
# 62.5

# %%
features = pd.read_csv("features.csv")
output = pd.read_csv("output.csv")

# %%
features.tail(10)
# Out:
#        temperature  humidity  precipitation  windspeed  age  weight  height  \
# 99990           -7        12             34         40   48    60.0   156.0
# 99991           14        14             98         30   51   113.0   200.0
# 99992          -13        45             19         24   60    41.0   178.0
# 99993          -18        79             91         20   16    54.0   157.0
# 99994          -18        42             80         24   31    46.0   149.0
# 99995           10         8             94         18   38    48.0   131.0
# 99996           17        85             77          6   45    76.0   173.0
# 99997           21        78             36         40   31    48.0   174.0
# 99998          -15        42             89         34   46    38.0   113.0
# 99999            5        88             78         39   37    95.0   134.0
#
#        sex  fatpercentage        bmi  cold_resistance  scoring_difference  \
# 99990    0      24.425799  24.654832             82.5           -7.516667
# 99991    1      40.230000  28.250000             70.0            0.000000
# 99992    0      13.128342  12.940285             32.5            9.533333
# 99993    0      13.769099  21.907582             57.5           16.866667
# 99994    0      15.793745  20.719787             85.0           -0.033333
# 99995    1      36.904478  27.970398            100.0            0.000000
# 99996    1      35.422117  25.393431             80.0            0.000000
# 99997    1      20.754970  15.854142             77.5            0.000000
# 99998    0      30.091489  29.759574             90.0           -6.033333
# 99999    1      66.598528  52.907106            100.0           -3.666667
#
#        adjusted_cold_resistance  preference_factor
# 99990                     80.85                 98
# 99991                     72.80                104
# 99992                     33.80                104
# 99993                     59.80                104
# 99994                     86.70                102
# 99995                     98.00                 98
# 99996                     76.80                 96
# 99997                     79.05                102
# 99998                     92.70                103
# 99999                     97.00                 97

# %%
output.tail(10)
# Out:
#        thermal  hoodie  fleece   wool  light_down  thick_down  wind_breaker  \
# 99990    False   False    True  False        True       False          True
# 99991    False    True    True  False       False       False          True
# 99992     True   False   False  False       False        True         False
# 99993    False   False   False   True        True        True         False
# 99994    False   False   False   True       False       False         False
# 99995     True    True    True  False        True        True         False
# 99996     True    True    True   True        True       False         False
# 99997     True    True    True   True       False        True          True
# 99998    False   False   False  False        True        True         False
# 99999    False   False    True  False        True       False          True
#
#        umbrella  winter_boots  user_feedback
# 99990      True         False              0
# 99991     False         False              1
# 99992     False         False              2
# 99993      True          True              2
# 99994     False         False              1
# 99995     False          True              1
# 99996      True         False              1
# 99997      True         False              1
# 99998     False          True              0
# 99999     False         False              1

# %%
r_values = pd.read_csv("R_values.csv")
r_values.tail(10)
# Out:
#        Attribute 1  Attribute 2  Attribute 3  Attribute 4
# 99990    -0.399245    -0.707471     0.022047    -0.006399
# 99991    -0.462212     0.043858     0.251649    -0.137407
# 99992    -0.841959    -0.857318     0.069331    -0.112978
# 99993     0.196163    -0.342578    -0.576297    -0.005956
# 99994    -0.080244    -0.441829    -0.255763     0.099569
# 99995     0.072192     0.707204     0.444989     0.730724
# 99996    -0.260917     0.355484     0.302514     0.253209
# 99997    -0.087666     0.606994     0.012968     0.352629
# 99998    -0.133847    -0.428275     0.269365     0.458528
# 99999     0.358103     0.523236     0.479077     0.552810

# %%
# Combining R values with CSV file

features["R1"] = r_values["Attribute 1"]
features["R2"] = r_values["Attribute 2"]
features["R3"] = r_values["Attribute 3"]
features["R4"] = r_values["Attribute 4"]

features.tail(10)
# Out:
#        temperature  humidity  precipitation  windspeed  age  weight  height  \
# 99990           -7        12             34         40   48    60.0   156.0
# 99991           14        14             98         30   51   113.0   200.0
# 99992          -13        45             19         24   60    41.0   178.0
# 99993          -18        79             91         20   16    54.0   157.0
# 99994          -18        42             80         24   31    46.0   149.0
# 99995           10         8             94         18   38    48.0   131.0
# 99996           17        85             77          6   45    76.0   173.0
# 99997           21        78             36         40   31    48.0   174.0
# 99998          -15        42             89         34   46    38.0   113.0
# 99999            5        88             78         39   37    95.0   134.0
#
#        sex  fatpercentage        bmi  cold_resistance  scoring_difference  \
# 99990    0      24.425799  24.654832             82.5           -7.516667
# 99991    1      40.230000  28.250000             70.0            0.000000
# 99992    0      13.128342  12.940285             32.5            9.533333
# 99993    0      13.769099  21.907582             57.5           16.866667
# 99994    0      15.793745  20.719787             85.0           -0.033333
# 99995    1      36.904478  27.970398            100.0            0.000000
# 99996    1      35.422117  25.393431             80.0            0.000000
# 99997    1      20.754970  15.854142             77.5            0.000000
# 99998    0      30.091489  29.759574             90.0           -6.033333
# 99999    1      66.598528  52.907106            100.0           -3.666667
#
#        adjusted_cold_resistance  preference_factor        R1        R2  \
# 99990                     80.85                 98 -0.399245 -0.707471
# 99991                     72.80                104 -0.462212  0.043858
# 99992                     33.80                104 -0.841959 -0.857318
# 99993                     59.80                104  0.196163 -0.342578
# 99994                     86.70                102 -0.080244 -0.441829
# 99995                     98.00                 98  0.072192  0.707204
# 99996                     76.80                 96 -0.260917  0.355484
# 99997                     79.05                102 -0.087666  0.606994
# 99998                     92.70                103 -0.133847 -0.428275
# 99999                     97.00                 97  0.358103  0.523236
#
#              R3        R4
# 99990  0.022047 -0.006399
# 99991  0.251649 -0.137407
# 99992  0.069331 -0.112978
# 99993 -0.576297 -0.005956
# 99994 -0.255763  0.099569
# 99995  0.444989  0.730724
# 99996  0.302514  0.253209
# 99997  0.012968  0.352629
# 99998  0.269365  0.458528
# 99999  0.479077  0.552810

# %%
# Splitting the set into X and Y
X = features
Y = output[["thermal", "hoodie", "fleece", "wool", "light_down", "thick_down", "wind_breaker", "umbrella", "winter_boots"]]

# %%
for i in Y.columns:
    Y[i] = Y[i].astype(int)
# Out:
# <ipython-input-8-d087100a50e2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i] = Y[i].astype(int)

# %%
X = X[['temperature', 'humidity', 'precipitation', 'windspeed', 'R1', 'R2', 'R3', 'R4']]

# %%
X.tail(10)
# Out:
#        temperature  humidity  precipitation  windspeed
# 99990           -7        12             34         40
# 99991           14        14             98         30
# 99992          -13        45             19         24
# 99993          -18        79             91         20
# 99994          -18        42             80         24
# 99995           10         8             94         18
# 99996           17        85             77          6
# 99997           21        78             36         40
# 99998          -15        42             89         34
# 99999            5        88             78         39

# %%
Y.tail(10)
# Out:
#        thermal  hoodie  fleece  wool  light_down  thick_down  wind_breaker  \
# 99990        0       0       1     0           1           0             1
# 99991        0       1       1     0           0           0             1
# 99992        1       0       0     0           0           1             0
# 99993        0       0       0     1           1           1             0
# 99994        0       0       0     1           0           0             0
# 99995        1       1       1     0           1           1             0
# 99996        1       1       1     1           1           0             0
# 99997        1       1       1     1           0           1             1
# 99998        0       0       0     0           1           1             0
# 99999        0       0       1     0           1           0             1
#
#        umbrella  winter_boots
# 99990         1             0
# 99991         0             0
# 99992         0             0
# 99993         1             1
# 99994         0             0
# 99995         0             1
# 99996         1             0
# 99997         1             0
# 99998         0             1
# 99999         0             0

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=10)

# %%
#https://www.analyticsvidhya.com/blog/2021/10/implementing-artificial-neural-networkclassification-in-python-from-scratch/

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units = 18,activation="relu"))

# %%
ann.add(tf.keras.layers.Dense(units = 24,activation="relu"))

# %%
ann.add(tf.keras.layers.Dense(units = 18,activation="relu"))

# %%
ann.add(tf.keras.layers.Dense(units = 9,activation="sigmoid"))

# %%
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
ann.fit(X_train,Y_train,batch_size=20,epochs = 30)
# Out:
# Epoch 1/30
# 3750/3750 [==============================] - 3s 706us/step - loss: 0.3801 - accuracy: 0.1901
# Epoch 2/30
# 3750/3750 [==============================] - 3s 718us/step - loss: 0.3489 - accuracy: 0.2001
# Epoch 3/30
# 3750/3750 [==============================] - 3s 704us/step - loss: 0.3407 - accuracy: 0.2021
# Epoch 4/30
# 3750/3750 [==============================] - 3s 727us/step - loss: 0.3369 - accuracy: 0.2008
# Epoch 5/30
# 3750/3750 [==============================] - 3s 700us/step - loss: 0.3349 - accuracy: 0.2040
# Epoch 6/30
# 3750/3750 [==============================] - 3s 700us/step - loss: 0.3339 - accuracy: 0.2019
# Epoch 7/30
# 3750/3750 [==============================] - 3s 701us/step - loss: 0.3330 - accuracy: 0.1995TA: 0s - loss: 0.3327 - accuracy: 0.
# Epoch 8/30
# 3750/3750 [==============================] - 3s 742us/step - loss: 0.3326 - accuracy: 0.2018
# Epoch 9/30
# 3750/3750 [==============================] - 3s 722us/step - loss: 0.3322 - accuracy: 0.2033 - ETA
# Epoch 10/30
# 3750/3750 [==============================] - 3s 701us/step - loss: 0.3319 - accuracy: 0.2018
# Epoch 11/30
# 3750/3750 [==============================] - 3s 760us/step - loss: 0.3317 - accuracy: 0.2027
# Epoch 12/30
# 3750/3750 [==============================] - 3s 766us/step - loss: 0.3314 - accuracy: 0.2017
# Epoch 13/30
# 3750/3750 [==============================] - 3s 763us/step - loss: 0.3312 - accuracy: 0.20040s - loss:
# Epoch 14/30
# 3750/3750 [==============================] - 3s 758us/step - loss: 0.3310 - accuracy: 0.1991
# Epoch 15/30
# 3750/3750 [==============================] - 3s 736us/step - loss: 0.3308 - accuracy: 0.2026
# Epoch 16/30
# 3750/3750 [==============================] - 3s 743us/step - loss: 0.3306 - accuracy: 0.20180s - loss: 0.3310 - accura
# Epoch 17/30
# 3750/3750 [==============================] - 3s 788us/step - loss: 0.3305 - accuracy: 0.2006
# Epoch 18/30
# 3750/3750 [==============================] - 3s 758us/step - loss: 0.3303 - accuracy: 0.20040s -
# Epoch 19/30
# 3750/3750 [==============================] - 3s 746us/step - loss: 0.3302 - accuracy: 0.2020
# Epoch 20/30
# 3750/3750 [==============================] - 3s 713us/step - loss: 0.3301 - accuracy: 0.2013
# Epoch 21/30
# 3750/3750 [==============================] - 3s 706us/step - loss: 0.3299 - accuracy: 0.20450s - loss: 0.3301 - ac
# Epoch 22/30
# 3750/3750 [==============================] - 3s 697us/step - loss: 0.3298 - accuracy: 0.2056
# Epoch 23/30
# 3750/3750 [==============================] - 3s 709us/step - loss: 0.3296 - accuracy: 0.20500s - loss: 0.3290 -  - ETA: 0s - loss: 0.329
# Epoch 24/30
# 3750/3750 [==============================] - 3s 732us/step - loss: 0.3296 - accuracy: 0.2022
# Epoch 25/30
# 3750/3750 [==============================] - 3s 701us/step - loss: 0.3294 - accuracy: 0.2036
# Epoch 26/30
# 3750/3750 [==============================] - 3s 719us/step - loss: 0.3293 - accuracy: 0.2069
# Epoch 27/30
# 3750/3750 [==============================] - 3s 751us/step - loss: 0.3293 - accuracy: 0.2041
# Epoch 28/30
# 3359/3750 [=========================>....] - ETA: 0s - loss: 0.3295 - accuracy: 0.2051 ETA: 0s - loss: 0.3292 - ac

# %%
ann.save("ANN.h5")

# %%
ann_model = tf.keras.models.load_model("ANN.h5")
encoder_model = tf.keras.models.load_model("encoder.h5")
test_data = np.array([[59, 76.350691, 165.034328, 1, 41.809198, 28.032665]])

weather_data = np.array([[-5 , 20 , 60, 27]])

encoded_test_data = encoder_model.predict(test_data)
#print(encoded_test_data)
final_data = np.concatenate((weather_data, encoded_test_data), axis=None)
print(final_data)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
suggested_clothing = ann_model.predict(sc.fit_transform([final_data]))
suggested_clothing

# %%
test_loss, test_accuracy = model.evaluate(X_test, Y_test)

# %%
'''
from sklearn.metrics import precision_score, recall_score, accuracy_score
preds = model.predict(D_test)
best_preds = np.asarray([np.argmax(line) for line in preds])

print("Precision = {}".format(precision_score(Y_test, best_preds, average='macro')))
print("Recall = {}".format(recall_score(Y_test, best_preds, average='macro')))
print("Accuracy = {}".format(accuracy_score(Y_test, best_preds)))
'''

# %%
#print(test_loss)
#print(test_accuracy)
